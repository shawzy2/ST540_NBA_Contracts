# %% [markdown]
# # Mining NBA Contracts
# Source: [Sporttrac](https://www.spotrac.com/nba/contracts/)

# %%
import json
import requests
from bs4 import BeautifulSoup
from urllib.request import urlopen
import pprint
import re 
import pandas as pd
import numpy as np
import time

# fix ssl certificate (needed for MacOS sometimes)
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

# %% [markdown]
# ### Sample of one page

# %%
# get html, convert to bs4 object
category = 'entry-level'
url = f'https://www.spotrac.com/nba/contracts/sort-value/type-{category}/limit-500/'
page = urlopen(url)
html = page.read().decode("utf-8")
soup = BeautifulSoup(html, 'html.parser')

# %%
players = []
for row in soup.find_all('tr'):
#     cell = [re.sub('\s+',' ',item.strip()) for item in row.find_all('td') if item not None]
    row_data = [category]
    for cell in row.find_all('td'):
        if cell is None:
            continue
        else:
            # look through this cell
            if '\n' in cell.text.strip(): # this cell is the 'name' cell
                for cell_text in cell.text.strip().split('\n'):
                    if cell_text != '\n':
                        row_data.append(cell_text)
                    if len(row_data) > 14:
                        break
            else:
                row_data.append(cell.text.strip())
#     pprint.pprint(row_data)

    row_data = [r for r in row_data if len(r) > 0]
    players.append(row_data)
    
# drop first frow
players = players[1:]

# %%
df = pd.DataFrame(players)
df.columns = ['category','categoryRank', 'lastName', 'fullName', 'position', 'empty', 'term',
              'signAge', 'contractLength', 'totalValue', 'aav', 'signBonus']
df = df.drop(['empty'], axis=1)

# %%
df
# Out:
#         category categoryRank    lastName         fullName  \
# 0    entry-level            1  Cunningham  Cade Cunningham
# 1    entry-level            2     Edwards  Anthony Edwards
# 2    entry-level            2  Williamson  Zion Williamson
# 3    entry-level            4       Green      Jalen Green
# 4    entry-level            5       Ayton    Deandre Ayton
# ..           ...          ...         ...              ...
# 139  entry-level          140      Butler     Jared Butler
# 140  entry-level          140     Dosunmu      Ayo Dosunmu
# 141  entry-level          142      Banton    Dalano Banton
# 142  entry-level          143       Nwora     Jordan Nwora
# 143  entry-level          143      Elleby        CJ Elleby
#
#                                 position  \
# 0                           Point Guard
# 1                        Shooting Guard
# 2                         Power Forward
# 3                        Shooting Guard
# 4                                Center
# ..                                   ...
# 139                         Point Guard
# 140                      Shooting Guard
# 141                         Point Guard
# 142                       Power Forward
# 143                       Small Forward
#
#                                           term signAge contractLength  \
# 0                         2021-2024 (FA: 2025)      19              4
# 1                         2020-2023 (FA: 2024)      19              4
# 2                         2019-2022 (FA: 2023)      18              4
# 3                         2021-2024 (FA: 2025)      19              4
# 4                         2018-2021 (FA: 2022)      19              4
# ..                                         ...     ...            ...
# 139                       2021-2022 (FA: 2023)      20              2
# 140                       2021-2022 (FA: 2023)      21              2
# 141                       2021-2022 (FA: 2023)      21              2
# 142                       2020-2021 (FA: 2022)      22              2
# 143                       2020-2021 (FA: 2022)      20              2
#
#       totalValue          aav signBonus
# 0    $45,599,089  $11,399,772        0-
# 1    $44,271,137  $11,067,784        0-
# 2    $44,271,137  $11,067,784        0-
# 3    $40,808,448  $10,202,112        0-
# 4    $40,379,230  $10,094,808        0-
# ..           ...          ...       ...
# 139   $2,488,776   $1,244,388        0-
# 140   $2,488,776   $1,244,388        0-
# 141   $2,488,775   $1,244,388        0-
# 142   $2,416,291   $1,208,146        0-
# 143   $2,416,291   $1,208,146        0-
#
# [144 rows x 11 columns]

# %% [markdown]
# ### Automate for all pages

# %%
def download_html(category):
    url = f'https://www.spotrac.com/nba/contracts/sort-value/type-{category}/limit-500/'
    page = urlopen(url)
    html = page.read().decode("utf-8")
    soup = BeautifulSoup(html, 'html.parser')
    return soup

def extract_players(soup, category):
    players = []
    for row in soup.find_all('tr'):
        row_data = [category]
        for cell in row.find_all('td'):
            if cell is None:
                continue
            else:
                # look through this cell
                if '\n' in cell.text.strip(): # this cell is the 'name' cell
                    for cell_text in cell.text.strip().split('\n'):
                        if cell_text != '\n':
                            row_data.append(cell_text)
                        if len(row_data) > 14:
                            break
                else:
                    row_data.append(cell.text.strip())

        row_data = [r for r in row_data if len(r) > 0]
        players.append(row_data)

    # drop first frow
    return players[1:]

# %%
categories = [
    'entry-level',
    'rookie-extension',
    'rookie-maximum-extension',
    'designated-rookie-extension',
    'veteran-extension',
    'designated-player-veteran-extension',
    'free-agent',
    'maximum',
    'rest-of-season'
]
players = []

for category in categories:
    try:
        soup = download_html(category)
        players.extend(extract_players(soup, category))
        time.sleep(0.5) # don't get caught scraping (we don't want to get banned)
    except:
        print('failed on ' + category)

# %%
df = pd.DataFrame(players)
df.columns = ['category','categoryRank', 'lastName', 'fullName', 'position', 'empty', 'term',
              'signAge', 'contractLength', 'totalValue', 'aav', 'signBonus']
df = df.drop(['empty'], axis=1)
df['position'] = df['position'].str.strip()
df['term'] = df['term'].str.strip()
df['signBonus'] = np.where(df['signBonus']=='0-', '$0', df['signBonus'])

# %%
df
# Out:
#         category categoryRank    lastName            fullName        position  \
# 0    entry-level            1  Cunningham     Cade Cunningham     Point Guard
# 1    entry-level            2     Edwards     Anthony Edwards  Shooting Guard
# 2    entry-level            2  Williamson     Zion Williamson   Power Forward
# 3    entry-level            4       Green         Jalen Green  Shooting Guard
# 4    entry-level            5       Ayton       Deandre Ayton          Center
# ..           ...          ...         ...                 ...             ...
# 384      maximum            4   Porzingis  Kristaps Porzingis   Power Forward
# 385      maximum            4      Ingram      Brandon Ingram   Small Forward
# 386      maximum            6       Jokic        Nikola Jokic          Center
# 387      maximum            7      Butler        Jimmy Butler   Small Forward
# 388      maximum            8     Russell    D'Angelo Russell     Point Guard
#
#                      term signAge contractLength    totalValue          aav  \
# 0    2021-2024 (FA: 2025)      19              4   $45,599,089  $11,399,772
# 1    2020-2023 (FA: 2024)      19              4   $44,271,137  $11,067,784
# 2    2019-2022 (FA: 2023)      18              4   $44,271,137  $11,067,784
# 3    2021-2024 (FA: 2025)      19              4   $40,808,448  $10,202,112
# 4    2018-2021 (FA: 2022)      19              4   $40,379,230  $10,094,808
# ..                    ...     ...            ...           ...          ...
# 384  2019-2023 (FA: 2024)      23              5  $158,253,000  $31,650,600
# 385  2020-2024 (FA: 2025)      23              5  $158,253,000  $31,650,600
# 386  2018-2022 (FA: 2023)      23              5  $147,710,050  $29,542,010
# 387  2019-2022 (FA: 2023)      29              4  $140,790,600  $35,197,650
# 388  2019-2022 (FA: 2023)      23              4  $117,325,500  $29,331,375
#
#     signBonus
# 0          $0
# 1          $0
# 2          $0
# 3          $0
# 4          $0
# ..        ...
# 384        $0
# 385        $0
# 386        $0
# 387        $0
# 388        $0
#
# [389 rows x 11 columns]

# %%
df['position']
# Out:
# 0         Point Guard
# 1      Shooting Guard
# 2       Power Forward
# 3      Shooting Guard
# 4              Center
#             ...
# 384     Power Forward
# 385     Small Forward
# 386            Center
# 387     Small Forward
# 388       Point Guard
# Name: position, Length: 389, dtype: object

# %%
df['signBonus'].unique()
# Out:
# array(['$0', '$300,000'], dtype=object)

# %%
df[df['signBonus']=='$300,000']
# Out:
#        category categoryRank lastName       fullName        position  \
# 242  free-agent           24  Beasley  Malik Beasley  Shooting Guard
#
#                      term signAge contractLength   totalValue          aav  \
# 242  2020-2023 (FA: 2024)      24              4  $60,000,000  $15,000,000
#
#     signBonus
# 242  $300,000

# %%
df.to_csv('../data/contracts.csv', index=False)
